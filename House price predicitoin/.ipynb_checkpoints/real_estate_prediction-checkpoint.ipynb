# %% [markdown]
# ## Model creation process:
#     1. import data
#     2. split train test then their feautres and labels
#     3. Pipeline the data:
#         1. impute, fill missing data using SimpleImputer
#         2. scale the data using StandardScaler
#     4. Create model piplined train feature and train label
#     5. Evalute and after low error, proceed otherwise use differnet model
#     6. Test model using pipelined test feature
#     7. Save model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##customizing matplotlib
plt.rcParams['figure.figsize'] = [10,8]# for 8:5 ratio
plt.rcParams['font.size'] = 14
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ## import the data

# %%
housing = pd.read_csv("real_estate_data.csv")
# cor = housing.corr()
# cor["MEDV"].sort_values()
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
housing.info()
##evey column is numeric type so no need to convert any object to numbers
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         441
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# MEDV       229
# dtype: int64

# %%
housing.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
housing[housing.RM.isnull()]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 10   0.22489  12.5   7.87     0  0.524 NaN  94.3  6.3467    5  311     15.2
# 35   0.06417   0.0   5.96     0  0.499 NaN  68.2  3.3603    5  279     19.2
# 63   0.12650  25.0   5.13     0  0.453 NaN  43.4  7.9809    8  284     19.7
# 96   0.11504   0.0   2.89     0  0.445 NaN  69.6  3.4952    2  276     18.0
# 135  0.55778   0.0  21.89     0  0.624 NaN  98.2  2.1107    4  437     21.2
#
#           B  LSTAT  MEDV
# 10   392.52  20.45  15.0
# 35   396.90   9.68  18.9
# 63   395.58   9.50  25.0
# 96   391.83  11.34  21.4
# 135  394.67  16.96  18.1

# %%
5/505*100
# Out:
# 0.9900990099009901

# %%
sns.heatmap(housing.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### filling the null values

# %%
housing.RM.describe()
# Out:
# count    501.000000
# mean       6.284341
# std        0.705587
# min        3.561000
# 25%        5.884000
# 50%        6.208000
# 75%        6.625000
# max        8.780000
# Name: RM, dtype: float64

# %%
housing.RM.fillna(housing.RM.mean(),inplace=True)

# %%
housing.skew()
# Out:
# CRIM       5.223149
# ZN         2.225666
# INDUS      0.295022
# CHAS       3.405904
# NOX        0.729308
# RM         0.405418
# AGE       -0.598963
# DIS        1.011781
# RAD        1.004815
# TAX        0.669956
# PTRATIO   -0.802325
# B         -2.890374
# LSTAT      0.906460
# MEDV       1.108098
# dtype: float64

# %%
housing.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
X = housing.drop("MEDV", axis=1)
y = housing.MEDV.copy()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=324)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (404,)
# (102, 13)
# (102,)

# %% [markdown]
# # Scaling the data
#     Scaling : transform the data such that mean will be 0 and std will be 1

# %%
#standard scaler will replace all the value such that standard deviation of each column will be one
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %% [markdown]
# ### checking the std and mean of scaled data

# %%
X_df = pd.DataFrame(X_train,columns=housing.columns[:-1])
X_df
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.106996 -0.495453  1.014461 -0.283221 -0.198868 -0.719828 -1.044010
# 1   -0.248735 -0.495453  1.228978  3.530817  0.423164  2.980913  0.893414
# 2   -0.404984  1.386958 -1.110411 -0.283221 -1.008361  1.285625 -1.550054
# 3   -0.392993  0.424837 -0.759648 -0.283221 -1.059487 -0.062674  0.362068
# 4   -0.407725 -0.495453 -0.856760 -0.283221 -0.343724 -0.428074 -0.386154
# ..        ...       ...       ...       ...       ...       ...       ...
# 399 -0.401934  0.341174 -0.600210 -0.283221 -0.778294  0.379205 -0.378924
# 400 -0.408261 -0.495453 -1.114759 -0.283221 -0.565270  1.043441  0.618705
# 401  0.226109 -0.495453  1.014461 -0.283221  1.173010  0.190840  0.969321
# 402 -0.391955  0.424837 -0.759648 -0.283221 -1.059487 -0.959180  0.264474
# 403 -0.179995 -0.495453  1.228978 -0.283221  2.689744 -0.794891  1.059685
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# 0    0.127325  1.675791  1.539002  0.792341  0.392351 -0.320521
# 1   -0.768707 -0.512229 -0.030473 -1.750751  0.342192 -1.321754
# 2    1.229374 -0.512229 -0.060311 -1.519561  0.365083 -1.385212
# 3    1.958537 -0.281912 -0.466107  0.283723  0.204057 -0.358596
# 4    0.457685 -0.512229 -1.098671  0.792341  0.437012 -0.479872
# ..        ...       ...       ...       ...       ...       ...
# 399  0.043659 -0.742547 -1.104639  0.052533  0.415243 -0.699861
# 400 -0.185775 -0.857706 -0.824162 -0.317371  0.437012 -1.014333
# 401 -0.993235  1.675791  1.539002  0.792341  0.437012  0.941597
# 402  1.911984 -0.281912 -0.466107  0.283723  0.163100 -0.027202
# 403 -1.018039 -0.512229 -0.030473 -1.750751 -1.077305  0.436750
#
# [404 rows x 13 columns]

# %%
X_df.std()
# Out:
# CRIM       1.00124
# ZN         1.00124
# INDUS      1.00124
# CHAS       1.00124
# NOX        1.00124
# RM         1.00124
# AGE        1.00124
# DIS        1.00124
# RAD        1.00124
# TAX        1.00124
# PTRATIO    1.00124
# B          1.00124
# LSTAT      1.00124
# dtype: float64

# %%
X_df.mean()
# Out:
# CRIM      -8.244230e-19
# ZN         1.232512e-16
# INDUS      4.105627e-16
# CHAS      -1.041521e-16
# NOX       -2.737084e-16
# RM         5.650046e-16
# AGE        9.893076e-18
# DIS        9.343461e-18
# RAD       -4.891577e-17
# TAX        1.371720e-16
# PTRATIO    7.436296e-16
# B         -5.853404e-16
# LSTAT      6.485461e-17
# dtype: float64

# %%
X_df.skew()
# Out:
# CRIM       5.142249
# ZN         2.158296
# INDUS      0.283104
# CHAS       3.259712
# NOX        0.729418
# RM         0.359261
# AGE       -0.600304
# DIS        1.044985
# RAD        1.023725
# TAX        0.670046
# PTRATIO   -0.784203
# B         -2.917229
# LSTAT      0.924920
# dtype: float64

# %% [markdown]
# ## Creating model
#     Model tried:
#         1. LinearRegressor
#         2. DecisionTreeRegressor
#         3. RandomForestRegressor(best)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
model = [LinearRegression(),DecisionTreeRegressor(),RandomForestRegressor()]
for i in model:
    i.fit(X_train, y_train)

# %% [markdown]
# ## Evaluting all model using rmse on train data

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = []
for c,i in enumerate(model):
    housing_predictions.append(i.predict(X_train)) 
    mse = mean_squared_error(y_train, housing_predictions[c])
    rmse = np.sqrt(mse)
    print(f"{i} RMSE value : {rmse}")
# Out:
# LinearRegression() RMSE value : 4.823462008208031
# DecisionTreeRegressor() RMSE value : 0.0
# RandomForestRegressor() RMSE value : 1.1976710485747168

# %% [markdown]
# ### NOTE
#     Decision tree is over fitted as the error is 0
#     Random forest model is better as the error is lower than linear regression model

# %%
sns.regplot(X_df.LSTAT,housing_predictions[0], color="red")
sns.regplot(X_df.LSTAT,y_train, color="blue")
# Out:
# C:\Users\Rahul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Rahul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>

# %%
sns.regplot(X_df.LSTAT,housing_predictions[1], color="red")
sns.regplot(X_df.LSTAT,y_train, color="blue")
## note how all the point is overlapped making it overfitted
# Out:
# C:\Users\Rahul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Rahul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>

# %%
sns.regplot(X_df.LSTAT,housing_predictions[2], color="red")
sns.regplot(X_df.LSTAT,y_train, color="blue")
# Out:
# C:\Users\Rahul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Rahul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>

# %% [markdown]
# ## Testing model on test data

# %%
X_test_prepared = scaler.transform(X_test)
final_predictions = []
for i in model:
    final_predictions.append(i.predict(X_test_prepared))

# %%
##evalulatind test data
for i,j in zip(final_predictions,model):
    final_mse = mean_squared_error(y_test, i)
    final_rmse = np.sqrt(final_mse)
    print(f"{j}----->{final_rmse}")
# Out:
# LinearRegression()----->4.162993449872926
# DecisionTreeRegressor()----->3.26232204082295
# RandomForestRegressor()----->2.8773171719230293

# %% [markdown]
# #### NOTE
#      Random forest has lowest error on test data
#      Since Decision tree was overfitted it has more error
